# %% [markdown]
# Kaggle notebook using the Applio-RVC-Fork
# https://github.com/IAHispano/Applio-RVC-Fork
#
# To use tensorboard, open up terminals on the lefthand side and create a new terminal.
# use tensorboard --logdir /notebooks/Applio-RVC-Fork/logs --bind_all
#
# tensorboard will give you a url, copy the first part into the NOTEBOOKID here
# https://tensorboard-NOTEBOOKID.clg07azjl.paperspacegradient.com
# open the link in a new tab and it should work

# %%
import git
from IPython.display import clear_output
next_message = "Step successfully completed, continue to the next step"

# !pip install gitpython
git.Repo.clone_from('https://github.com/IAHispano/Applio-RVC-Fork.git', 'Applio-RVC-Fork')
# %cd /notebooks/Applio-RVC-Fork

print(next_message)
# Out:
# Step successfully completed, continue to the next step

# %%
# %cd /notebooks/Applio-RVC-Fork
# !apt-get update
# !apt-get -y install build-essential python3-dev ffmpeg
# !apt -y install -qq aria2

# !pip install --upgrade setuptools wheel pip gdown

# !pip install faiss-gpu fairseq gradio ffmpeg ffmpeg-python praat-parselmouth pyworld numpy==1.23.5 numba==0.56.4 librosa==0.9.1 nltk

# !pip install --upgrade lxml
# !pip install bark
# !pip install gdown

# !wget https://raw.githubusercontent.com/IAHispano/Applio-Utilities-Kaggle/main/requirements2.txt
# !wget https://raw.githubusercontent.com/IAHispano/Applio-Utilities-Kaggle/main/requirements1.txt
# !pip install -r requirements1.txt
# !pip install -r requirements2.txt

print(next_message)

# %%
# %cd /notebooks/Applio-RVC-Fork
# !make basev1

# !make basev2

# !wget https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/rmvpe.pt

print(next_message)
# Out:
# /notebooks/Applio-RVC-Fork
# mkdir -p pretrained uvr5_weights
# git pull
# aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/D32k.pth -d pretrained -o D32k.pth
# aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/D40k.pth -d pretrained -o D40k.pth
# aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/D48k.pth -d pretrained -o D48k.pth
# aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/G32k.pth -d pretrained -o G32k.pth
# aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/G40k.pth -d pretrained -o G40k.pth
# aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/G48k.pth -d pretrained -o G48k.pth
# aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/f0D32k.pth -d pretrained -o f0D32k.pth
# aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/f0D40k.pth -d pretrained -o f0D40k.pth
# aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/f0D48k.pth -d pretrained -o f0D48k.pth
# aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/f0G32k.pth -d pretrained -o f0G32k.pth
# aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/f0G40k.pth -d pretrained -o f0G40k.pth
# aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained/f0G48k.pth -d pretrained -o f0G48k.pth
# aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/uvr5_weights/HP2-人声vocals+非人声instrumentals.pth -d uvr5_weights -o HP2-人声vocals+非人声instrumentals.pth
# aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/uvr5_weights/HP5-主旋律人声vocals+其他instrumentals.pth -d uvr5_weights -o HP5-主旋律人声vocals+其他instrumentals.pth
# aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/hubert_base.pt -d ./ -o hubert_base.pt
# Already up to date.
# [#c0b28d 16MiB/104MiB(15%) CN:16 DL:26MiB ETA:3s]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# c0b28d|OK  |    77MiB/s|pretrained/D32k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 096cab|OK  |   159MiB/s|pretrained/D40k.pth
#
# Status Legend:
# (OK):download completed.
# [#6cecb0 17MiB/104MiB(16%) CN:16 DL:28MiB ETA:3s]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 6cecb0|OK  |    97MiB/s|pretrained/D48k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 6ce70d|OK  |   152MiB/s|pretrained/G32k.pth
#
# Status Legend:
# (OK):download completed.
# [#83b2ba 21MiB/69MiB(30%) CN:16 DL:31MiB ETA:1s]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 83b2ba|OK  |    79MiB/s|pretrained/G40k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 61ea09|OK  |   250MiB/s|pretrained/G48k.pth
#
# Status Legend:
# (OK):download completed.
# [#011b99 103MiB/104MiB(99%) CN:3 DL:97MiB]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 011b99|OK  |    96MiB/s|pretrained/f0D32k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 1c5f88|OK  |   185MiB/s|pretrained/f0D40k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 3b405a|OK  |   180MiB/s|pretrained/f0D48k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# a0c210|OK  |   108MiB/s|pretrained/f0G32k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 6c8864|OK  |   118MiB/s|pretrained/f0G40k.pth
#
# Status Legend:
# (OK):download completed.
# [#c94091 66MiB/69MiB(95%) CN:9 DL:137MiB]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# c94091|OK  |   126MiB/s|pretrained/f0G48k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# c3e18d|OK  |   202MiB/s|uvr5_weights/HP2-人声vocals+非人声instrumentals.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 2fe54c|OK  |   152MiB/s|uvr5_weights/HP5-主旋律人声vocals+其他instrumentals.pth
#
# Status Legend:
# (OK):download completed.
# [#3136ee 179MiB/180MiB(99%) CN:1 DL:164MiB]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 3136ee|OK  |   163MiB/s|.//hubert_base.pt
#
# Status Legend:
# (OK):download completed.
# mkdir -p pretrained_v2 uvr5_weights
# git pull
# aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/D32k.pth -d pretrained_v2 -o D32k.pth
# aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/D40k.pth -d pretrained_v2 -o D40k.pth
# aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/D48k.pth -d pretrained_v2 -o D48k.pth
# aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/G32k.pth -d pretrained_v2 -o G32k.pth
# aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/G40k.pth -d pretrained_v2 -o G40k.pth
# aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/G48k.pth -d pretrained_v2 -o G48k.pth
# aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/f0D32k.pth -d pretrained_v2 -o f0D32k.pth
# aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/f0D40k.pth -d pretrained_v2 -o f0D40k.pth
# aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/f0D48k.pth -d pretrained_v2 -o f0D48k.pth
# aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/f0G32k.pth -d pretrained_v2 -o f0G32k.pth
# aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/f0G40k.pth -d pretrained_v2 -o f0G40k.pth
# aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/pretrained_v2/f0G48k.pth -d pretrained_v2 -o f0G48k.pth
# aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/uvr5_weights/HP2-人声vocals+非人声instrumentals.pth -d uvr5_weights -o HP2-人声vocals+非人声instrumentals.pth
# aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/uvr5_weights/HP5-主旋律人声vocals+其他instrumentals.pth -d uvr5_weights -o HP5-主旋律人声vocals+其他instrumentals.pth
# aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/hubert_base.pt -d ./ -o hubert_base.pt
# Already up to date.
# [#7a9e50 136MiB/136MiB(99%) CN:1 DL:84MiB]0m]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 7a9e50|OK  |    84MiB/s|pretrained_v2/D32k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 8a04e7|OK  |   299MiB/s|pretrained_v2/D40k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 5967de|OK  |   232MiB/s|pretrained_v2/D48k.pth
#
# Status Legend:
# (OK):download completed.
# [#8e7faa 69MiB/70MiB(99%) CN:2 DL:88MiB]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 8e7faa|OK  |    88MiB/s|pretrained_v2/G32k.pth
#
# Status Legend:
# (OK):download completed.
# [#8eed38 68MiB/69MiB(98%) CN:2 DL:43MiB]s]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 8eed38|OK  |    36MiB/s|pretrained_v2/G40k.pth
#
# Status Legend:
# (OK):download completed.
# [#9e2e33 70MiB/71MiB(97%) CN:2 DL:46MiB]s]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 9e2e33|OK  |    36MiB/s|pretrained_v2/G48k.pth
#
# Status Legend:
# (OK):download completed.
# [#7dc6b8 117MiB/136MiB(86%) CN:15 DL:225MiB]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 7dc6b8|OK  |   175MiB/s|pretrained_v2/f0D32k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 6c505d|OK  |   295MiB/s|pretrained_v2/f0D40k.pth
#
# Status Legend:
# (OK):download completed.
# [#a1557a 131MiB/136MiB(96%) CN:6 DL:274MiB]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# a1557a|OK  |   148MiB/s|pretrained_v2/f0D48k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# ba8415|OK  |   107MiB/s|pretrained_v2/f0G32k.pth
#
# Status Legend:
# (OK):download completed.
# [#ec1b8a 67MiB/69MiB(97%) CN:2 DL:61MiB]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# ec1b8a|OK  |    61MiB/s|pretrained_v2/f0G40k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 33739f|OK  |   151MiB/s|pretrained_v2/f0G48k.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 0a8f51|OK  |       0B/s|uvr5_weights/HP2-人声vocals+非人声instrumentals.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# c98c39|OK  |       0B/s|uvr5_weights/HP5-主旋律人声vocals+其他instrumentals.pth
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 9d2fc0|OK  |       0B/s|.//hubert_base.pt
#
# Status Legend:
# (OK):download completed.
# --2023-09-12 02:24:29--  https://huggingface.co/lj1995/VoiceConversionWebUI/resolve/main/rmvpe.pt
# Resolving huggingface.co (huggingface.co)... 18.164.124.47, 18.164.124.11, 18.164.124.27, ...
# Connecting to huggingface.co (huggingface.co)|18.164.124.47|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/ef/97/ef977053f017cde1fc0f89ac7ef0b33172a3d8fb8a840bb24e78b1c0f35f1e72/a5ed4719f59085d1affc5d81354c70828c740584f2d24e782523345a6a278962?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27rmvpe.pt%3B+filename%3D%22rmvpe.pt%22%3B&Expires=1694741932&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=Av0o1uAJ4rIuliDb4WSDyztaVJZ8-miPRW9Ivqm2X6O%7EXOXSYwLbGrqUlCTv-tU3xxsLXRqC%7E7YOzf3sMQ7XOIaUaBa0-e7u2Om-KH7FcKPnwMJuyv22Wa4gglMBkYtNLMG3Wjzz1llrx4skBoaJ8BuW92elo00V71aqPRm7lLexWDOpX%7EzCJzVTYyuNA5kSlYnnU36gKReUVL5N8xuHQKTSGXxlSnbhq4lkTbcU4teKbkgg2GUqM3aL8gKCJA01ttMkJtuaKdDni0rBElmnXpvGLJC-VS12jjv0UyrWsKjS22xHBR35lUylqTNQF9YYpe2HdNbKWszXuYrUFwiyag__&Key-Pair-Id=KVTP0A1DKRTAX [following]
# --2023-09-12 02:24:29--  https://cdn-lfs.huggingface.co/repos/ef/97/ef977053f017cde1fc0f89ac7ef0b33172a3d8fb8a840bb24e78b1c0f35f1e72/a5ed4719f59085d1affc5d81354c70828c740584f2d24e782523345a6a278962?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27rmvpe.pt%3B+filename%3D%22rmvpe.pt%22%3B&Expires=1694741932&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=Av0o1uAJ4rIuliDb4WSDyztaVJZ8-miPRW9Ivqm2X6O%7EXOXSYwLbGrqUlCTv-tU3xxsLXRqC%7E7YOzf3sMQ7XOIaUaBa0-e7u2Om-KH7FcKPnwMJuyv22Wa4gglMBkYtNLMG3Wjzz1llrx4skBoaJ8BuW92elo00V71aqPRm7lLexWDOpX%7EzCJzVTYyuNA5kSlYnnU36gKReUVL5N8xuHQKTSGXxlSnbhq4lkTbcU4teKbkgg2GUqM3aL8gKCJA01ttMkJtuaKdDni0rBElmnXpvGLJC-VS12jjv0UyrWsKjS22xHBR35lUylqTNQF9YYpe2HdNbKWszXuYrUFwiyag__&Key-Pair-Id=KVTP0A1DKRTAX
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 18.161.34.13, 18.161.34.60, 18.161.34.26, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|18.161.34.13|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 181189687 (173M) [binary/octet-stream]
# Saving to: ‘rmvpe.pt.2’
#
# rmvpe.pt.2          100%[===================>] 172.80M  44.2MB/s    in 3.9s
#
# 2023-09-12 02:24:33 (44.2 MB/s) - ‘rmvpe.pt.2’ saved [181189687/181189687]
#
# Step successfully completed, continue to the next step

# %%
# %cd /notebooks/Applio-RVC-Fork
# !python infer-web.py --paperspace --pycmd python
# Out:
# /notebooks/Applio-RVC-Fork
# Using Language: en_US
# Running on local URL:  http://0.0.0.0:7865
# Running on public URL: https://71998feb97aae4faf9.gradio.live
# python trainset_preprocess_pipeline_print.py /notebooks/Applio-RVC-Fork/datasets/makoto 40000 6 /notebooks/Applio-RVC-Fork/logs/makoto False
# 2023-09-12 02:27:44 | INFO | httpx | HTTP Request: POST http://localhost:7865/api/predict "HTTP/1.1 200 OK"
# start preprocess
# ['trainset_preprocess_pipeline_print.py', '/notebooks/Applio-RVC-Fork/datasets/makoto', '40000', '6', '/notebooks/Applio-RVC-Fork/logs/makoto', 'False']
# 2023-09-12 02:27:45 | INFO | httpx | HTTP Request: POST http://localhost:7865/api/predict "HTTP/1.1 200 OK"
# thread:0:   0%|                                           | 0/3 [00:00<?, ?it/s]
# thread:1:   0%|                                           | 0/3 [00:00<?, ?it/s]
#
# thread:2:   0%|                                           | 0/3 [00:00<?, ?it/s]
#
#
# thread:3:   0%|                                           | 0/2 [00:00<?, ?it/s]
#
#
#
# thread:4:   0%|                                           | 0/2 [00:00<?, ?it/s]
#
#
#
#
# thread:5:   0%|                                           | 0/2 [00:00<?, ?it/s]2023-09-12 02:27:46 | INFO | httpx | HTTP Request: POST http://localhost:7865/api/predict "HTTP/1.1 200 OK"
# 2023-09-12 02:27:47 | INFO | httpx | HTTP Request: POST http://localhost:7865/api/predict "HTTP/1.1 200 OK"
#
# thread:1:  33%|███████████▋                       | 1/3 [00:02<00:04,  2.40s/it]
#
#
#
# thread:0:  33%|███████████▋                       | 1/3 [00:02<00:05,  2.95s/it]
#
#
#
#
# thread:5:  50%|█████████████████▌                 | 1/2 [00:02<00:02,  2.96s/it]2023-09-12 02:27:48 | INFO | httpx | HTTP Request: POST http://localhost:7865/api/predict "HTTP/1.1 200 OK"
#
#
#
# thread:3:  50%|█████████████████▌                 | 1/2 [00:03<00:03,  3.00s/it]
#
# thread:2:  33%|███████████▋                       | 1/3 [00:03<00:06,  3.10s/it]2023-09-12 02:27:49 | INFO | httpx | HTTP Request: POST http://localhost:7865/api/predict "HTTP/1.1 200 OK"
#
# thread:0:  67%|███████████████████████▎           | 2/3 [00:04<00:02,  2.15s/it]
#
#
#
# thread:4: 100%|███████████████████████████████████| 2/2 [00:04<00:00,  2.36s/it]
#
#
#
#
#
# thread:5: 100%|███████████████████████████████████| 2/2 [00:04<00:00,  2.47s/it]
# 2023-09-12 02:27:50 | INFO | httpx | HTTP Request: POST http://localhost:7865/api/predict "HTTP/1.1 200 OK"
#
#
#
# thread:3: 100%|███████████████████████████████████| 2/2 [00:05<00:00,  2.58s/it]
#
#
# thread:2:  67%|███████████████████████▎           | 2/3 [00:05<00:02,  2.61s/it]2023-09-12 02:27:51 | INFO | httpx | HTTP Request: POST http://localhost:7865/api/predict "HTTP/1.1 200 OK"
#
# thread:1: 100%|███████████████████████████████████| 3/3 [00:06<00:00,  2.11s/it]
# thread:0: 100%|███████████████████████████████████| 3/3 [00:07<00:00,  2.34s/it]
# 2023-09-12 02:27:52 | INFO | httpx | HTTP Request: POST http://localhost:7865/api/predict "HTTP/1.1 200 OK"
# 2023-09-12 02:27:53 | INFO | httpx | HTTP Request: POST http://localhost:7865/api/predict "HTTP/1.1 200 OK"
#
#
# thread:2: 100%|███████████████████████████████████| 3/3 [00:08<00:00,  2.69s/it]
# end preprocess
# start preprocess
# ['trainset_preprocess_pipeline_print.py', '/notebooks/Applio-RVC-Fork/datasets/makoto', '40000', '6', '/notebooks/Applio-RVC-Fork/logs/makoto', 'False']
# end preprocess
#
# 2023-09-12 02:27:54 | INFO | httpx | HTTP Request: POST http://localhost:7865/api/predict "HTTP/1.1 200 OK"
# 2023-09-12 02:27:54 | INFO | httpx | HTTP Request: POST http://localhost:7865/api/predict "HTTP/1.1 200 OK"
# 2023-09-12 02:27:54 | INFO | httpx | HTTP Request: POST http://localhost:7865/reset "HTTP/1.1 200 OK"
# python extract_f0_print.py /notebooks/Applio-RVC-Fork/logs/makoto 6 rmvpe 64
# 2023-09-12 02:28:06 | INFO | httpx | HTTP Request: POST http://localhost:7865/api/predict "HTTP/1.1 200 OK"
# ['extract_f0_print.py', '/notebooks/Applio-RVC-Fork/logs/makoto', '6', 'rmvpe', '64']
# Using f0 method: rmvpe
# thread:0, f0ing, Hop-Length:64: 100%|████████| 64/64 [00:00<00:00, 50571.86it/s]
#
#   0%|                                                    | 0/64 [00:00<?, ?it/s]
# thread:1, f0ing, Hop-Length:64: 100%|████████| 64/64 [00:00<00:00, 50638.64it/s]
#
#
#   0%|                                                    | 0/64 [00:00<?, ?it/s]
#
# thread:2, f0ing, Hop-Length:64: 100%|████████| 64/64 [00:00<00:00, 33867.71it/s]
#
#
#
#   0%|                                                    | 0/64 [00:00<?, ?it/s]
#
#
# thread:3, f0ing, Hop-Length:64: 100%|████████| 64/64 [00:00<00:00, 48957.77it/s]
#
#
#
#
#   0%|                                                    | 0/63 [00:00<?, ?it/s]
#
#
#
# thread:4, f0ing, Hop-Length:64: 100%|████████| 63/63 [00:00<00:00, 51985.27it/s]
#
#
#
#
#
#   0%|                                                    | 0/63 [00:00<?, ?it/s]
#
#
#
#
# thread:5, f0ing, Hop-Length:64: 100%|████████| 63/63 [00:00<00:00, 50274.19it/s]
# python extract_feature_print.py cuda:0 1 0 0 /notebooks/Applio-RVC-Fork/logs/makoto v2
# 2023-09-12 02:28:07 | INFO | httpx | HTTP Request: POST http://localhost:7865/api/predict "HTTP/1.1 200 OK"
# 2023-09-12 02:28:08 | INFO | httpx | HTTP Request: POST http://localhost:7865/api/predict "HTTP/1.1 200 OK"
# 2023-09-12 02:28:09 | INFO | httpx | HTTP Request: POST http://localhost:7865/api/predict "HTTP/1.1 200 OK"
# 2023-09-12 02:28:10 | INFO | httpx | HTTP Request: POST http://localhost:7865/api/predict "HTTP/1.1 200 OK"
# 2023-09-12 02:28:11 | INFO | httpx | HTTP Request: POST http://localhost:7865/api/predict "HTTP/1.1 200 OK"
# 2023-09-12 02:28:12 | INFO | httpx | HTTP Request: POST http://localhost:7865/api/predict "HTTP/1.1 200 OK"
# ['extract_feature_print.py', 'cuda:0', '1', '0', '0', '/notebooks/Applio-RVC-Fork/logs/makoto', 'v2']
# /notebooks/Applio-RVC-Fork/logs/makoto
# load model(s) from hubert_base.pt
# 2023-09-12 02:28:12 | INFO | fairseq.tasks.hubert_pretraining | current directory is /notebooks/Applio-RVC-Fork
# 2023-09-12 02:28:12 | INFO | fairseq.tasks.hubert_pretraining | HubertPretrainingTask Config {'_name': 'hubert_pretraining', 'data': 'metadata', 'fine_tuning': False, 'labels': ['km'], 'label_dir': 'label', 'label_rate': 50.0, 'sample_rate': 16000, 'normalize': False, 'enable_padding': False, 'max_keep_size': None, 'max_sample_size': 250000, 'min_sample_size': 32000, 'single_target': False, 'random_crop': True, 'pad_audio': False}
# 2023-09-12 02:28:12 | INFO | fairseq.models.hubert.hubert | HubertModel Config: {'_name': 'hubert', 'label_rate': 50.0, 'extractor_mode': default, 'encoder_layers': 12, 'encoder_embed_dim': 768, 'encoder_ffn_embed_dim': 3072, 'encoder_attention_heads': 12, 'activation_fn': gelu, 'layer_type': transformer, 'dropout': 0.1, 'attention_dropout': 0.1, 'activation_dropout': 0.0, 'encoder_layerdrop': 0.05, 'dropout_input': 0.1, 'dropout_features': 0.1, 'final_dim': 256, 'untie_final_proj': True, 'layer_norm_first': False, 'conv_feature_layers': '[(512,10,5)] + [(512,3,2)] * 4 + [(512,2,2)] * 2', 'conv_bias': False, 'logit_temp': 0.1, 'target_glu': False, 'feature_grad_mult': 0.1, 'mask_length': 10, 'mask_prob': 0.8, 'mask_selection': static, 'mask_other': 0.0, 'no_mask_overlap': False, 'mask_min_space': 1, 'mask_channel_length': 10, 'mask_channel_prob': 0.0, 'mask_channel_selection': static, 'mask_channel_other': 0.0, 'no_mask_channel_overlap': False, 'mask_channel_min_space': 1, 'conv_pos': 128, 'conv_pos_groups': 16, 'latent_temp': [2.0, 0.5, 0.999995], 'skip_masked': False, 'skip_nomask': False, 'checkpoint_activations': False, 'required_seq_len_multiple': 2, 'depthwise_conv_kernel_size': 31, 'attn_type': '', 'pos_enc_type': 'abs', 'fp16': False}
# 2023-09-12 02:28:13 | INFO | httpx | HTTP Request: POST http://localhost:7865/api/predict "HTTP/1.1 200 OK"
# 2023-09-12 02:28:14 | INFO | httpx | HTTP Request: POST http://localhost:7865/api/predict "HTTP/1.1 200 OK"
# 2023-09-12 02:28:15 | INFO | httpx | HTTP Request: POST http://localhost:7865/api/predict "HTTP/1.1 200 OK"
# 2023-09-12 02:28:16 | INFO | httpx | HTTP Request: POST http://localhost:7865/api/predict "HTTP/1.1 200 OK"
# move model to cuda
# all-feature-382
# file 0_15.wav, shape (184, 768):   2%|▏         | 7/382 [00:00<00:38,  9.76it/s]2023-09-12 02:28:17 | INFO | httpx | HTTP Request: POST http://localhost:7865/api/predict "HTTP/1.1 200 OK"
# file 11_22.wav, shape (184, 768):  17%|█▍      | 66/382 [00:01<00:05, 57.64it/s]2023-09-12 02:28:18 | INFO | httpx | HTTP Request: POST http://localhost:7865/api/predict "HTTP/1.1 200 OK"
# file 13_20.wav, shape (184, 768):  30%|██▏    | 116/382 [00:02<00:05, 49.30it/s]2023-09-12 02:28:19 | INFO | httpx | HTTP Request: POST http://localhost:7865/api/predict "HTTP/1.1 200 OK"
# file 14_37.wav, shape (147, 768):  41%|██▉    | 158/382 [00:03<00:05, 43.94it/s]2023-09-12 02:28:20 | INFO | httpx | HTTP Request: POST http://localhost:7865/api/predict "HTTP/1.1 200 OK"
# file 2_14.wav, shape (184, 768):  49%|███▉    | 189/382 [00:04<00:05, 35.53it/s]2023-09-12 02:28:21 | INFO | httpx | HTTP Request: POST http://localhost:7865/api/predict "HTTP/1.1 200 OK"
# file 3_22.wav, shape (184, 768):  60%|████▊   | 230/382 [00:05<00:03, 41.60it/s]2023-09-12 02:28:22 | INFO | httpx | HTTP Request: POST http://localhost:7865/api/predict "HTTP/1.1 200 OK"
# file 4_3.wav, shape (150, 768):  68%|██████   | 259/382 [00:07<00:03, 35.80it/s]2023-09-12 02:28:23 | INFO | httpx | HTTP Request: POST http://localhost:7865/api/predict "HTTP/1.1 200 OK"
# file 6_0.wav, shape (184, 768):  76%|██████▊  | 291/382 [00:08<00:02, 30.54it/s]2023-09-12 02:28:24 | INFO | httpx | HTTP Request: POST http://localhost:7865/api/predict "HTTP/1.1 200 OK"
# file 8_21.wav, shape (184, 768):  90%|███████▏| 343/382 [00:09<00:00, 51.69it/s]2023-09-12 02:28:25 | INFO | httpx | HTTP Request: POST http://localhost:7865/api/predict "HTTP/1.1 200 OK"
# file 9_8.wav, shape (184, 768): 100%|█████████| 382/382 [00:09<00:00, 38.51it/s]
# all-feature-done
# 2023-09-12 02:28:26 | INFO | httpx | HTTP Request: POST http://localhost:7865/api/predict "HTTP/1.1 200 OK"
# 2023-09-12 02:28:27 | INFO | httpx | HTTP Request: POST http://localhost:7865/api/predict "HTTP/1.1 200 OK"
# ['extract_f0_print.py', '/notebooks/Applio-RVC-Fork/logs/makoto', '6', 'rmvpe', '64']
# ['extract_feature_print.py', 'cuda:0', '1', '0', '0', '/notebooks/Applio-RVC-Fork/logs/makoto', 'v2']
# /notebooks/Applio-RVC-Fork/logs/makoto
# load model(s) from hubert_base.pt
# move model to cuda
# all-feature-382
# all-feature-done
#
# 2023-09-12 02:28:28 | INFO | httpx | HTTP Request: POST http://localhost:7865/api/predict "HTTP/1.1 200 OK"
# 2023-09-12 02:28:28 | INFO | httpx | HTTP Request: POST http://localhost:7865/api/predict "HTTP/1.1 200 OK"
# 2023-09-12 02:28:28 | INFO | httpx | HTTP Request: POST http://localhost:7865/reset "HTTP/1.1 200 OK"
# 2023-09-12 02:29:03 | INFO | httpx | HTTP Request: POST http://localhost:7865/api/predict "HTTP/1.1 200 OK"
# 2023-09-12 02:29:34 | INFO | httpx | HTTP Request: POST http://localhost:7865/api/predict "HTTP/1.1 200 OK"
# 2023-09-12 02:29:37 | INFO | httpx | HTTP Request: POST http://localhost:7865/api/predict "HTTP/1.1 200 OK"
# 2023-09-12 02:29:37 | INFO | httpx | HTTP Request: POST http://localhost:7865/api/predict "HTTP/1.1 200 OK"
# 2023-09-12 02:29:37 | INFO | httpx | HTTP Request: POST http://localhost:7865/reset "HTTP/1.1 200 OK"
# 2023-09-12 02:30:10 | INFO | httpx | HTTP Request: POST http://localhost:7865/api/predict "HTTP/1.1 200 OK"
# 2023-09-12 02:30:11 | INFO | httpx | HTTP Request: POST http://localhost:7865/reset "HTTP/1.1 200 OK"
# 2023-09-12 02:30:13 | INFO | httpx | HTTP Request: POST http://localhost:7865/api/predict "HTTP/1.1 200 OK"
# 2023-09-12 02:30:13 | INFO | httpx | HTTP Request: POST http://localhost:7865/reset "HTTP/1.1 200 OK"
# write filelist done
# use gpus: 0
# python train_nsf_sim_cache_sid_load_pretrain.py -e makoto -sr 40k -f0 1 -bs 4 -g 0 -te 10 -se 10 -pg pretrained_v2/f0G40k.pth -pd pretrained_v2/f0D40k.pth -l 1 -c 0 -sw 0 -v v2 -li 97
# DEBUG:tensorflow:Falling back to TensorFlow client; we recommended you install the Cloud TPU client directly with pip install cloud-tpu-client.
# DEBUG:h5py._conv:Creating converter from 7 to 5
# DEBUG:h5py._conv:Creating converter from 5 to 7
# DEBUG:h5py._conv:Creating converter from 7 to 5
# DEBUG:h5py._conv:Creating converter from 5 to 7
# DEBUG:jaxlib.mlir._mlir_libs:Initializing MLIR with module: _site_initialize_0
# DEBUG:jaxlib.mlir._mlir_libs:Registering dialects from initializer <module 'jaxlib.mlir._mlir_libs._site_initialize_0' from '/usr/local/lib/python3.9/dist-packages/jaxlib/mlir/_mlir_libs/_site_initialize_0.so'>
# DEBUG:jax._src.path:etils.epath found. Using etils.epath for file I/O.
# DEBUG:tensorflow:Falling back to TensorFlow client; we recommended you install the Cloud TPU client directly with pip install cloud-tpu-client.
# DEBUG:h5py._conv:Creating converter from 7 to 5
# DEBUG:h5py._conv:Creating converter from 5 to 7
# DEBUG:h5py._conv:Creating converter from 7 to 5
# DEBUG:h5py._conv:Creating converter from 5 to 7
# DEBUG:jaxlib.mlir._mlir_libs:Initializing MLIR with module: _site_initialize_0
# DEBUG:jaxlib.mlir._mlir_libs:Registering dialects from initializer <module 'jaxlib.mlir._mlir_libs._site_initialize_0' from '/usr/local/lib/python3.9/dist-packages/jaxlib/mlir/_mlir_libs/_site_initialize_0.so'>
# DEBUG:jax._src.path:etils.epath found. Using etils.epath for file I/O.
# INFO:makoto:{'train': {'log_interval': 97, 'seed': 1234, 'epochs': 20000, 'learning_rate': 0.0001, 'betas': [0.8, 0.99], 'eps': 1e-09, 'batch_size': 4, 'fp16_run': True, 'lr_decay': 0.999875, 'segment_size': 12800, 'init_lr_ratio': 1, 'warmup_epochs': 0, 'c_mel': 45, 'c_kl': 1.0}, 'data': {'max_wav_value': 32768.0, 'sampling_rate': 40000, 'filter_length': 2048, 'hop_length': 400, 'win_length': 2048, 'n_mel_channels': 125, 'mel_fmin': 0.0, 'mel_fmax': None, 'training_files': './logs/makoto/filelist.txt'}, 'model': {'inter_channels': 192, 'hidden_channels': 192, 'filter_channels': 768, 'n_heads': 2, 'n_layers': 6, 'kernel_size': 3, 'p_dropout': 0, 'resblock': '1', 'resblock_kernel_sizes': [3, 7, 11], 'resblock_dilation_sizes': [[1, 3, 5], [1, 3, 5], [1, 3, 5]], 'upsample_rates': [10, 10, 2, 2], 'upsample_initial_channel': 512, 'upsample_kernel_sizes': [16, 16, 4, 4], 'use_spectral_norm': False, 'gin_channels': 256, 'spk_embed_dim': 109}, 'model_dir': './logs/makoto', 'experiment_dir': './logs/makoto', 'save_every_epoch': 10, 'name': 'makoto', 'total_epoch': 10, 'pretrainG': 'pretrained_v2/f0G40k.pth', 'pretrainD': 'pretrained_v2/f0D40k.pth', 'version': 'v2', 'gpus': '0', 'sample_rate': '40k', 'if_f0': 1, 'if_latest': 1, 'save_every_weights': '0', 'if_cache_data_in_gpu': 0}
# INFO:torch.distributed.distributed_c10d:Added key: store_based_barrier_key:1 to store for rank: 0
# INFO:torch.distributed.distributed_c10d:Rank 0: Completed store-based barrier for key:store_based_barrier_key:1 with 1 nodes.
# gin_channels: 256 self.spk_embed_dim: 109
# INFO:makoto:loaded pretrained pretrained_v2/f0G40k.pth
# <All keys matched successfully>
# INFO:makoto:loaded pretrained pretrained_v2/f0D40k.pth
# <All keys matched successfully>
# DEBUG:tensorflow:Falling back to TensorFlow client; we recommended you install the Cloud TPU client directly with pip install cloud-tpu-client.
# DEBUG:h5py._conv:Creating converter from 7 to 5
# DEBUG:h5py._conv:Creating converter from 5 to 7
# DEBUG:h5py._conv:Creating converter from 7 to 5
# DEBUG:h5py._conv:Creating converter from 5 to 7
# DEBUG:jaxlib.mlir._mlir_libs:Initializing MLIR with module: _site_initialize_0
# DEBUG:jaxlib.mlir._mlir_libs:Registering dialects from initializer <module 'jaxlib.mlir._mlir_libs._site_initialize_0' from '/usr/local/lib/python3.9/dist-packages/jaxlib/mlir/_mlir_libs/_site_initialize_0.so'>
# DEBUG:jax._src.path:etils.epath found. Using etils.epath for file I/O.
# DEBUG:tensorflow:Falling back to TensorFlow client; we recommended you install the Cloud TPU client directly with pip install cloud-tpu-client.
# DEBUG:h5py._conv:Creating converter from 7 to 5
# DEBUG:h5py._conv:Creating converter from 5 to 7
# DEBUG:h5py._conv:Creating converter from 7 to 5
# DEBUG:h5py._conv:Creating converter from 5 to 7
# DEBUG:jaxlib.mlir._mlir_libs:Initializing MLIR with module: _site_initialize_0
# DEBUG:jaxlib.mlir._mlir_libs:Registering dialects from initializer <module 'jaxlib.mlir._mlir_libs._site_initialize_0' from '/usr/local/lib/python3.9/dist-packages/jaxlib/mlir/_mlir_libs/_site_initialize_0.so'>
# DEBUG:jax._src.path:etils.epath found. Using etils.epath for file I/O.
# DEBUG:tensorflow:Falling back to TensorFlow client; we recommended you install the Cloud TPU client directly with pip install cloud-tpu-client.
# DEBUG:h5py._conv:Creating converter from 7 to 5
# DEBUG:h5py._conv:Creating converter from 5 to 7
# DEBUG:h5py._conv:Creating converter from 7 to 5
# DEBUG:h5py._conv:Creating converter from 5 to 7
# DEBUG:jaxlib.mlir._mlir_libs:Initializing MLIR with module: _site_initialize_0
# DEBUG:jaxlib.mlir._mlir_libs:Registering dialects from initializer <module 'jaxlib.mlir._mlir_libs._site_initialize_0' from '/usr/local/lib/python3.9/dist-packages/jaxlib/mlir/_mlir_libs/_site_initialize_0.so'>
# DEBUG:jax._src.path:etils.epath found. Using etils.epath for file I/O.
# DEBUG:tensorflow:Falling back to TensorFlow client; we recommended you install the Cloud TPU client directly with pip install cloud-tpu-client.
# DEBUG:h5py._conv:Creating converter from 7 to 5
# DEBUG:h5py._conv:Creating converter from 5 to 7
# DEBUG:h5py._conv:Creating converter from 7 to 5
# DEBUG:h5py._conv:Creating converter from 5 to 7
# DEBUG:jaxlib.mlir._mlir_libs:Initializing MLIR with module: _site_initialize_0
# DEBUG:jaxlib.mlir._mlir_libs:Registering dialects from initializer <module 'jaxlib.mlir._mlir_libs._site_initialize_0' from '/usr/local/lib/python3.9/dist-packages/jaxlib/mlir/_mlir_libs/_site_initialize_0.so'>
# DEBUG:jax._src.path:etils.epath found. Using etils.epath for file I/O.
# /usr/local/lib/python3.9/dist-packages/torch/functional.py:641: UserWarning: stft with return_complex=False is deprecated. In a future pytorch release, stft will return complex tensors for all inputs, and return_complex=False will raise an error.
# Note: you can still call torch.view_as_real on the complex output to recover the old return format. (Triggered internally at ../aten/src/ATen/native/SpectralOps.cpp:862.)
#   return _VF.stft(input, n_fft, hop_length, win_length, window,  # type: ignore[attr-defined]
# /usr/local/lib/python3.9/dist-packages/torch/functional.py:641: UserWarning: stft with return_complex=False is deprecated. In a future pytorch release, stft will return complex tensors for all inputs, and return_complex=False will raise an error.
# Note: you can still call torch.view_as_real on the complex output to recover the old return format. (Triggered internally at ../aten/src/ATen/native/SpectralOps.cpp:862.)
#   return _VF.stft(input, n_fft, hop_length, win_length, window,  # type: ignore[attr-defined]
# /usr/local/lib/python3.9/dist-packages/torch/functional.py:641: UserWarning: stft with return_complex=False is deprecated. In a future pytorch release, stft will return complex tensors for all inputs, and return_complex=False will raise an error.
# Note: you can still call torch.view_as_real on the complex output to recover the old return format. (Triggered internally at ../aten/src/ATen/native/SpectralOps.cpp:862.)
#   return _VF.stft(input, n_fft, hop_length, win_length, window,  # type: ignore[attr-defined]
# /usr/local/lib/python3.9/dist-packages/torch/functional.py:641: UserWarning: stft with return_complex=False is deprecated. In a future pytorch release, stft will return complex tensors for all inputs, and return_complex=False will raise an error.
# Note: you can still call torch.view_as_real on the complex output to recover the old return format. (Triggered internally at ../aten/src/ATen/native/SpectralOps.cpp:862.)
#   return _VF.stft(input, n_fft, hop_length, win_length, window,  # type: ignore[attr-defined]
# /usr/local/lib/python3.9/dist-packages/torch/functional.py:641: UserWarning: stft with return_complex=False is deprecated. In a future pytorch release, stft will return complex tensors for all inputs, and return_complex=False will raise an error.
# Note: you can still call torch.view_as_real on the complex output to recover the old return format. (Triggered internally at ../aten/src/ATen/native/SpectralOps.cpp:862.)
#   return _VF.stft(input, n_fft, hop_length, win_length, window,  # type: ignore[attr-defined]
# INFO:torch.nn.parallel.distributed:Reducer buckets have been rebuilt in this iteration.
# /usr/local/lib/python3.9/dist-packages/torch/autograd/__init__.py:200: UserWarning: Grad strides do not match bucket view strides. This may indicate grad was not created according to the gradient layout contract, or that the param's strides changed since DDP was constructed.  This is not an error, but may impair performance.
# grad.sizes() = [64, 1, 4], strides() = [4, 1, 1]
# bucket_view.sizes() = [64, 1, 4], strides() = [4, 4, 1] (Triggered internally at ../torch/csrc/distributed/c10d/reducer.cpp:323.)
#   Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# INFO:makoto:Train Epoch: 1 [0%]
# DEBUG:matplotlib:matplotlib data path: /usr/local/lib/python3.9/dist-packages/matplotlib/mpl-data
# DEBUG:matplotlib:CONFIGDIR=/root/.config/matplotlib
# DEBUG:matplotlib:interactive is False
# DEBUG:matplotlib:platform is linux
# INFO:torch.nn.parallel.distributed:Reducer buckets have been rebuilt in this iteration.
# INFO:makoto:====> Epoch: 1 [2023-09-12 02:31:30] | (0:00:42.825709)
# INFO:makoto:Train Epoch: 2 [0%]
# INFO:makoto:====> Epoch: 2 [2023-09-12 02:32:08] | (0:00:37.495866)
# INFO:makoto:Train Epoch: 3 [0%]
# INFO:makoto:====> Epoch: 3 [2023-09-12 02:32:45] | (0:00:37.275307)
# INFO:makoto:Train Epoch: 4 [0%]
# INFO:makoto:====> Epoch: 4 [2023-09-12 02:33:23] | (0:00:37.528196)
# INFO:makoto:Train Epoch: 5 [0%]
# INFO:makoto:====> Epoch: 5 [2023-09-12 02:34:00] | (0:00:37.566151)
# INFO:makoto:Train Epoch: 6 [0%]
# INFO:makoto:====> Epoch: 6 [2023-09-12 02:34:38] | (0:00:37.187179)
# INFO:makoto:Train Epoch: 7 [0%]
# INFO:makoto:====> Epoch: 7 [2023-09-12 02:35:15] | (0:00:37.413180)
# INFO:makoto:Train Epoch: 8 [0%]
# INFO:makoto:====> Epoch: 8 [2023-09-12 02:35:52] | (0:00:37.422052)
# INFO:makoto:Train Epoch: 9 [0%]
# INFO:makoto:====> Epoch: 9 [2023-09-12 02:36:30] | (0:00:37.372610)
# INFO:makoto:Train Epoch: 10 [0%]
# INFO:makoto:Saving model and optimizer state at epoch 10 to ./logs/makoto/G_2333333.pth
# INFO:makoto:Saving model and optimizer state at epoch 10 to ./logs/makoto/D_2333333.pth
# INFO:makoto:====> Epoch: 10 [2023-09-12 02:37:09] | (0:00:39.653595)
# INFO:makoto:Training is done. The program is closed.
# INFO:makoto:Saving final ckpt: Success.
# 2023-09-12 02:37:12 | INFO | httpx | HTTP Request: POST http://localhost:7865/api/predict "HTTP/1.1 200 OK"
# 2023-09-12 02:37:13 | INFO | httpx | HTTP Request: POST http://localhost:7865/reset "HTTP/1.1 200 OK"
# /usr/lib/python3.9/multiprocessing/resource_tracker.py:216: UserWarning: resource_tracker: There appear to be 20 leaked semaphore objects to clean up at shutdown
#   warnings.warn('resource_tracker: There appear to be %d '
# ^C
# Keyboard interruption in main thread... closing server.
# Killing tunnel 0.0.0.0:7865 <> https://71998feb97aae4faf9.gradio.live
